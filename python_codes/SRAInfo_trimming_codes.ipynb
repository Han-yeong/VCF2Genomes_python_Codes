# %%
import pandas as pd
df = pd.read_csv('SraRunInfo_1.csv')
# Out:
# c:\users\김한영\appdata\local\programs\python\python37\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (34,40) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
import numpy as np

# %%
def isInt(x):
    try:
        _ = int(x)
        return False
    except ValueError:
        return True
m1 = df['InsertSize'] < 500
m2 = (df['LibraryStrategy'] == 'WGS') |  (df['LibraryStrategy'] == 'WGA') 
m3 = df['LibraryLayout'] != 'SINGLE'
m4 = df['Model'].str.contains('Illumina Genome Analyzer')
m4 = ~m4
m5 = ~df['LibraryName'].isna()
m6 = ['RIL' not in str(x) for x in df['LibraryName'].values]
m7 = ['DNA' not in str(x) for x in df['LibraryName'].values]
m8 = [len(str(x)) > 2 for x in df['LibraryName'].values]
m9 = ['CW' not in str(x) for x in df['LibraryName'].values]
m10 = ['HRF' not in str(x) for x in df['LibraryName'].values]
m11 = ['unspecified' not in str(x) for x in df['LibraryName'].values]
m12 = ['Cas9' not in str(x) for x in df['LibraryName'].values]
m13 = np.array(['RANDOM' in str(x) for x in df['LibrarySelection'].values])
m14 = np.array(['RANDOM PCR' in str(x) for x in df['LibrarySelection'].values])
m15 = [isInt(str(x).replace('W','').replace('D','').replace('GC','').replace('L','')) for x in df['LibraryName'].values]
m16 = [isInt(str(x).replace('C','').replace('GS','')) for x in df['LibraryName'].values]
m17 = [isInt(str(x).replace('L_T','').replace('L_Z','').replace('rice_','')) for x in df['LibraryName'].values]
m18 = [isInt(str(x).replace('IRGC','')) for x in df['LibraryName'].values]
m19 = np.array(['CBE-' not in str(x) for x in df['LibraryName'].values])
m20 = np.array(['HF1-' not in str(x) for x in df['LibraryName'].values])
m21 = np.array(['JS_' not in str(x) for x in df['LibraryName'].values])
m22 = np.array(['GD_' not in str(x) for x in df['LibraryName'].values])
m23 = np.array(['LN_W' not in str(x) for x in df['LibraryName'].values])
m24 = np.array(['NX_' not in str(x) for x in df['LibraryName'].values])
m25 = np.array(['HT_' not in str(x) for x in df['LibraryName'].values])
m26 = [isInt(str(x).replace('R','').replace('H','')) for x in df['LibraryName'].values]
m27 = np.array(['NIPB' not in str(x) for x in df['LibraryName'].values])
m28 = np.array(['SAGC' not in str(x) for x in df['LibraryName'].values])
m29 = np.array(['ABE-' not in str(x) for x in df['LibraryName'].values])
m30 = [isInt(str(x).replace('PS','').replace('VR','').replace('RiceE','')) for x in df['LibraryName'].values]
m31 = np.array(['DG1_' not in str(x) for x in df['LibraryName'].values])
m32 = np.array(['LN_C' not in str(x) for x in df['LibraryName'].values])
m33 = [isInt(str(x).replace('VP','').replace('Control-#','')) for x in df['LibraryName'].values]
m34 = np.array(['IBRC_' not in str(x) for x in df['LibraryName'].values])
m35 = np.array(['sgRNA' not in str(x) for x in df['LibraryName'].values])
df_sub = df[(m35&m34&m33&m32&m31&m30&m27&m29&m28&m26&m22&m23&m24&m25&m21
             &m17&m20&m19&m18&m1&m2&m3&m4&m5&m6&m7&m8&m9&m10&m11&m12&(m13|m14)
             &m15&m16)]
df_sub.shape
# Out:
# (2369, 47)

# %%
df_sub.to_excel('./test_handork.xlsx')

# %%
for x in df_sub['LibraryName'].values:
    # print(x)
# Out:
#   File "<ipython-input-231-4f9af03cf514>", line 2
#     # print(x)
#               ^
# SyntaxError: unexpected EOF while parsing

# %%
fff

# %%
def isInt(x):
    try:
        _ = int(x)
        return False
    except ValueError:
        return True

# %%
int(09)

# %%
isInt(9)

# %%
df['LibraryStrategy'].unique()
# Out:
# array(['WGS', 'OTHER', 'Bisulfite-Seq', 'AMPLICON', 'RAD-Seq', 'ChIP-Seq',
#        'Hi-C', 'Targeted-Capture', 'ChIA-PET', 'WXS', 'ATAC-seq',
#        'Tn-Seq', 'WCS', 'WGA', 'MBD-Seq', 'MeDIP-Seq', 'miRNA-Seq',
#        'RNA-Seq', 'MNase-Seq', 'POOLCLONE', 'DNase-Hypersensitivity'],
#       dtype=object)

# %%
for x in df_sub.LibraryName:
    if str(x)[0] == 'W':
        print(x)
# Out:
# WRC34_ARC 7291
# WRC35_ARC 5955
# WRC36_RATUL
# WRC37_ARC 7047
# WRC38_ARC 11094
# WRC40_NEPAL 555
# WRC41_KALUHEENATI
# WRC42_LOCAL BASMATI
# WRC46_KHAO NOK
# WRC47_JAGUARY
# WRC50_REXMONT
# WRC51_URASAN 1
# WRC52_KHAU TAN CHIEM
# WRC55_TUPA 729
# WRC57_MILYANG 23
# WRC58_NEANG MENH
# WRC61_RADIN GOI SESAT
# WRC64_PADI KUNING
# WRC65_RAMBHOG
# WRC66_BINGALA
# WRC67_PHULBA
# WRC97_CHIN GALAY
# WRC98_DEEJIAOHUALUO
# WRC99_HONG CHEUH ZAI
# WRC04_Jena035
# WRC06_PULUIK_ARANG
# WRC09_RYOU SUISAN_KOUMAI
# WRC11_JINGUOYIN
# WRC12_DAHONGGU
# WRC13_ASU
# WRC14_IR58
# WRC15_CO13
# WRC16_VARY_FUTSI
# WRC17_KEIBOBA
# WRC18_QINGYU(SEIYU)
# WRC20_TADUKAN
# WRC21_SHWE NANG GYI
# WRC22_CALOTOC
# WRC23_LEBED_
# WRC24_PINULUPOT 1
# WRC26_JHONA 2
# WRC27_NEPAL 8
# WRC28_JARJAN
# WRC29_KALO DHAN
# WRC31_SHONI
# WRC33_SURJAMUKHI
# WT-3
# WT-2
# WT-1
# W24_P03-H
# W24_P15-H
# W24_P18-H
# W24_P18-S
# W24_P34-H
# W24_P34-S
# W24_P41-H
# W24_P42-H
# W24_P47-S
# WT-#1
# WT-#10
# WT-#11
# WT-#12
# WT-#2
# ...

# %%
df_sub['LibraryName']

# %%
df.LibrarySelection.unique()

# %%
a=1
b=2
print(a+b)

# %%
df_sub.to_excel('SraRunInfo_1.sub.xlsx')

# %%
df_sub['LibraryName'].head(10)
# Out:
# 279       Cheongcheong
# 285           Hanareum
# 286         Minghui 63
# 293         TN13007672
# 294     NTCDTN13007671
# 295      NTCDT13007670
# 296            Nampung
# 299           Takanari
# 305    C9285_HiSeq2000
# 311           Naba_#71
# Name: LibraryName, dtype: object

# %%
idx_1 = df[df['LibrarySelection']=='Restriction Digest'].index
idx_2 = df_1[df_1['LibraryStrategy']=='OTHER'].index
idx_3 = df_2[df_2['LibraryLayout']=='SINGLE'].index
idx_4 = df_3[df_3['Model'].str.contains('Illumina Genome Analyzer').isnull()].index
idx_5 = df_4[df_4['LibraryName'].str.isnumeric().isnull()].index
#idx_6 = df_5[df_5['LibraryName'].str.isidentifier().isnull()].index
df_1 = df.drop(idx_1, errors ='ignore')
df_2 = df_1.drop(idx_2, errors ='ignore')
df_3 = df_2.drop(idx_3, errors ='ignore')
df_4 = df_3.drop(idx_4, errors ='ignore')
df_5 = df_4.drop(idx_5, errors ='ignore')


df_5
# Out:
# c:\users\김한영\appdata\local\programs\python\python37\lib\site-packages\IPython\core\interactiveshell.py:3063: DtypeWarning: Columns (34,40) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
#                Run          ReleaseDate             LoadDate     spots  \
# 0      SRR11593305  2020-04-23 04:55:25  2020-04-23 04:49:11  47921365
# 1      SRR11593294  2020-04-23 04:47:33  2020-04-23 04:40:13  49266920
# 2      SRR11593316  2020-04-23 04:53:28  2020-04-23 04:46:16  45296792
# 3      SRR11593283  2020-04-23 04:27:30  2020-04-23 04:22:50  16746851
# 4      SRR11593322  2020-04-23 04:32:55  2020-04-23 04:28:40  16852161
# ...            ...                  ...                  ...       ...
# 53841    SRR189231  2012-04-13 00:00:00  2014-05-30 12:08:23  21232506
# 53842    SRR189232  2012-04-13 00:00:00  2014-05-30 12:06:02  22022280
# ...

# %%
df
# Out:
#                Run          ReleaseDate             LoadDate     spots  \
# 0      SRR11593305  2020-04-23 04:55:25  2020-04-23 04:49:11  47921365
# 1      SRR11593294  2020-04-23 04:47:33  2020-04-23 04:40:13  49266920
# 2      SRR11593316  2020-04-23 04:53:28  2020-04-23 04:46:16  45296792
# 3      SRR11593283  2020-04-23 04:27:30  2020-04-23 04:22:50  16746851
# 4      SRR11593322  2020-04-23 04:32:55  2020-04-23 04:28:40  16852161
# ...            ...                  ...                  ...       ...
# 53866    SRR015213  2011-12-05 21:25:40  2014-05-26 05:04:48   5813441
# 53867    SRR015214  2011-12-05 21:25:40  2014-05-26 05:04:57   7225219
# 53868    SRR015215  2011-12-05 21:25:40  2014-05-26 05:05:01   7303954
# 53869    SRR015216  2011-12-05 21:25:40  2014-05-26 05:05:04   7232353
# 53870    SRR015217  2011-12-05 21:25:40  2014-05-26 05:05:01   7176196
#
#              bases  spots_with_mates  avgLength  size_MB AssemblyName  \
# ...

# %%
df
# Out:
#                Run          ReleaseDate             LoadDate     spots  \
# 0      SRR11593305  2020-04-23 04:55:25  2020-04-23 04:49:11  47921365
# 1      SRR11593294  2020-04-23 04:47:33  2020-04-23 04:40:13  49266920
# 2      SRR11593316  2020-04-23 04:53:28  2020-04-23 04:46:16  45296792
# 3      SRR11593283  2020-04-23 04:27:30  2020-04-23 04:22:50  16746851
# 4      SRR11593322  2020-04-23 04:32:55  2020-04-23 04:28:40  16852161
# ...            ...                  ...                  ...       ...
# 53866    SRR015213  2011-12-05 21:25:40  2014-05-26 05:04:48   5813441
# 53867    SRR015214  2011-12-05 21:25:40  2014-05-26 05:04:57   7225219
# 53868    SRR015215  2011-12-05 21:25:40  2014-05-26 05:05:01   7303954
# 53869    SRR015216  2011-12-05 21:25:40  2014-05-26 05:05:04   7232353
# 53870    SRR015217  2011-12-05 21:25:40  2014-05-26 05:05:01   7176196
#
#              bases  spots_with_mates  avgLength  size_MB AssemblyName  \
# ...
